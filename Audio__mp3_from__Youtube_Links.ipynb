# %%
# !pip install pytube
# Out:
# Collecting pytube
#   Downloading pytube-15.0.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 2.0 MB/s eta 0:00:00
# Installing collected packages: pytube
# Successfully installed pytube-15.0.0

# %%
# !apt install ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 24 not upgraded.

# %%
from pytube import YouTube
import os

# Ask user for the YouTube video URL
url = input("https://www.youtube.com/watch?v=XezfOVE9RFM")

# Create a YouTube object from the URL
yt = YouTube(url)

# Get the audio stream
audio_stream = yt.streams.filter(only_audio=True).first()

# Download the audio stream
output_path = "/content/output"
filename = "audio.mp3"
audio_stream.download(output_path=output_path, filename=filename)

# Convert the downloaded file to .mp3
os.system(f"ffmpeg -i {output_path}/{filename} {output_path}/{filename}.mp3")

print(f"Audio downloaded to {output_path}/{filename}")
# Out:
# https://www.youtube.com/watch?v=zgtD2Cerotshttps://www.youtube.com/watch?v=zgtD2Cerots
# Audio downloaded to /content/output/audio.mp3

# %%
from IPython.display import Audio
Audio("/content/output/audio.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
